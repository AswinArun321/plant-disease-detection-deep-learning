# %% [markdown]
# # 05. Model Evaluation & Empirical Comparison Study
# Tabulates test accuracy, precision, recall, F1-score, parameter count, and training duration.

# %%
import os, sys
sys.path.insert(0, "..")
import pandas as pd
from IPython.display import display, Image as IPImage

df = pd.read_csv("../reports/model_comparison.csv")
display(df)

# %%
IPImage(filename="../reports/figures/model_comparison_chart.png")
